# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data1 = pd.read_csv('Combined_Ozone.csv')

# %%
data1.head()
# Out:
#        Date Source    Site ID  POC  Daily Max 8-hour Ozone Concentration  \
# 0  3/1/2018    AQS  371010002    1                                 0.037
# 1  3/2/2018    AQS  371010002    1                                 0.046
# 2  3/3/2018    AQS  371010002    1                                 0.047
# 3  3/4/2018    AQS  371010002    1                                 0.045
# 4  3/5/2018    AQS  371010002    1                                 0.046
#
#   Units  Daily AQI Value    Local Site Name  Daily Obs Count  \
# 0   ppm               34  West Johnston Co.               17
# 1   ppm               43  West Johnston Co.               17
# 2   ppm               44  West Johnston Co.               17
# 3   ppm               42  West Johnston Co.               17
# 4   ppm               43  West Johnston Co.               17
#
#    Percent Complete  ...  AQS Parameter Description Method Code  CBSA Code  \
# 0               100  ...                      Ozone          47      39580
# 1               100  ...                      Ozone          47      39580
# 2               100  ...                      Ozone          47      39580
# 3               100  ...                      Ozone          47      39580
# 4               100  ...                      Ozone          47      39580
#
#      CBSA Name State FIPS Code           State County FIPS Code    County  \
# 0  Raleigh, NC              37  North Carolina              101  Johnston
# 1  Raleigh, NC              37  North Carolina              101  Johnston
# 2  Raleigh, NC              37  North Carolina              101  Johnston
# 3  Raleigh, NC              37  North Carolina              101  Johnston
# 4  Raleigh, NC              37  North Carolina              101  Johnston
#
#   Site Latitude  Site Longitude
# 0      35.59095        -78.4622
# 1      35.59095        -78.4622
# 2      35.59095        -78.4622
# 3      35.59095        -78.4622
# 4      35.59095        -78.4622
#
# [5 rows x 21 columns]

# %%
data1.tail()
# Out:
#             Date  Source    Site ID  POC  \
# 2418  10/13/2024  AirNow  371010002    1
# 2419  10/14/2024  AirNow  371010002    1
# 2420  10/15/2024  AirNow  371010002    1
# 2421  10/16/2024  AirNow  371010002    1
# 2422  10/17/2024  AirNow  371010002    1
#
#       Daily Max 8-hour Ozone Concentration Units  Daily AQI Value  \
# 2418                                 0.050   ppm               46
# 2419                                 0.050   ppm               46
# 2420                                 0.036   ppm               33
# 2421                                 0.031   ppm               29
# 2422                                 0.035   ppm               32
#
#         Local Site Name  Daily Obs Count  Percent Complete  ...  \
# 2418  West Johnston Co.               24               100  ...
# 2419  West Johnston Co.               24               100  ...
# 2420  West Johnston Co.               24               100  ...
# 2421  West Johnston Co.               24               100  ...
# 2422  West Johnston Co.               22                92  ...
#
#       AQS Parameter Description Method Code  CBSA Code    CBSA Name  \
# 2418                      Ozone          19      39580  Raleigh, NC
# 2419                      Ozone          19      39580  Raleigh, NC
# 2420                      Ozone          19      39580  Raleigh, NC
# 2421                      Ozone          19      39580  Raleigh, NC
# 2422                      Ozone          19      39580  Raleigh, NC
#
#      State FIPS Code           State County FIPS Code    County Site Latitude  \
# 2418              37  North Carolina              101  Johnston      35.59095
# 2419              37  North Carolina              101  Johnston      35.59095
# 2420              37  North Carolina              101  Johnston      35.59095
# 2421              37  North Carolina              101  Johnston      35.59095
# 2422              37  North Carolina              101  Johnston      35.59095
#
#       Site Longitude
# 2418        -78.4622
# 2419        -78.4622
# 2420        -78.4622
# 2421        -78.4622
# 2422        -78.4622
#
# [5 rows x 21 columns]

# %%
np.shape(data1)
# Out:
# (2423, 21)

# %%
data1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2423 entries, 0 to 2422
# Data columns (total 21 columns):
#  #   Column                                Non-Null Count  Dtype
# ---  ------                                --------------  -----
#  0   Date                                  2423 non-null   object
#  1   Source                                2423 non-null   object
#  2   Site ID                               2423 non-null   int64
#  3   POC                                   2423 non-null   int64
#  4   Daily Max 8-hour Ozone Concentration  2423 non-null   float64
#  5   Units                                 2423 non-null   object
#  6   Daily AQI Value                       2423 non-null   int64
#  7   Local Site Name                       2423 non-null   object
#  8   Daily Obs Count                       2423 non-null   int64
#  9   Percent Complete                      2423 non-null   int64
#  10  AQS Parameter Code                    2423 non-null   int64
#  11  AQS Parameter Description             2423 non-null   object
#  12  Method Code                           2423 non-null   int64
#  13  CBSA Code                             2423 non-null   int64
#  14  CBSA Name                             2423 non-null   object
#  15  State FIPS Code                       2423 non-null   int64
#  16  State                                 2423 non-null   object
#  17  County FIPS Code                      2423 non-null   int64
#  18  County                                2423 non-null   object
#  19  Site Latitude                         2423 non-null   float64
#  20  Site Longitude                        2423 non-null   float64
# dtypes: float64(3), int64(10), object(8)
# memory usage: 397.6+ KB

# %%
data1.describe()
# Out:
#             Site ID          POC  Daily Max 8-hour Ozone Concentration  \
# count  2.423000e+03  2423.000000                           2423.000000
# mean   2.557106e+08     0.689228                              0.042374
# std    1.717424e+08     0.462905                              0.009539
# min    0.000000e+00     0.000000                              0.012000
# 25%    0.000000e+00     0.000000                              0.036000
# 50%    3.710100e+08     1.000000                              0.043000
# 75%    3.710100e+08     1.000000                              0.049000
# max    3.710100e+08     1.000000                              0.082000
#
#        Daily AQI Value  Daily Obs Count  Percent Complete  AQS Parameter Code  \
# count      2423.000000      2423.000000       2423.000000         2423.000000
# mean         27.619067        12.626909         72.515477        30464.576971
# std          20.887072         9.130505         52.155912        20460.867459
# min           0.000000         0.000000          0.000000            0.000000
# 25%           0.000000         0.000000          0.000000            0.000000
# 50%          33.000000        17.000000        100.000000        44201.000000
# 75%          43.000000        17.000000        100.000000        44201.000000
# max         140.000000        34.000000        200.000000        44201.000000
#
#        Method Code     CBSA Code  State FIPS Code  County FIPS Code  \
# count  2423.000000   2423.000000      2423.000000       2423.000000
# mean     30.140322  27279.653322        25.501444         69.612051
# std      21.576227  18321.783082        17.127488         46.753413
# min       0.000000      0.000000         0.000000          0.000000
# 25%       0.000000      0.000000         0.000000          0.000000
# 50%      47.000000  39580.000000        37.000000        101.000000
# 75%      47.000000  39580.000000        37.000000        101.000000
# max      47.000000  39580.000000        37.000000        101.000000
#
#        Site Latitude  Site Longitude
# count    2423.000000     2423.000000
# mean       24.530287      -54.078363
# std        16.475232       36.320551
# min         0.000000      -78.462200
# 25%         0.000000      -78.462200
# 50%        35.590950      -78.462200
# 75%        35.590950        0.000000
# max        35.590950        0.000000

# %%
print(data1.isnull().sum()) # No Missing Values
# Out:
# Date                                    0
# Source                                  0
# Site ID                                 0
# POC                                     0
# Daily Max 8-hour Ozone Concentration    0
# Units                                   0
# Daily AQI Value                         0
# Local Site Name                         0
# Daily Obs Count                         0
# Percent Complete                        0
# AQS Parameter Code                      0
# AQS Parameter Description               0
# Method Code                             0
# CBSA Code                               0
# CBSA Name                               0
# State FIPS Code                         0
# State                                   0
# County FIPS Code                        0
# County                                  0
# Site Latitude                           0
# Site Longitude                          0
# dtype: int64

# %%
data1.dtypes
# Out:
# Date                                     object
# Source                                   object
# Site ID                                   int64
# POC                                       int64
# Daily Max 8-hour Ozone Concentration    float64
# Units                                    object
# Daily AQI Value                           int64
# Local Site Name                          object
# Daily Obs Count                           int64
# Percent Complete                          int64
# AQS Parameter Code                        int64
# AQS Parameter Description                object
# Method Code                               int64
# CBSA Code                                 int64
# CBSA Name                                object
# State FIPS Code                           int64
# State                                    object
# County FIPS Code                          int64
# County                                   object
# Site Latitude                           float64
# Site Longitude                          float64
# dtype: object

# %%
print(data1["POC"].duplicated().sum())
# Out:
# 2421

# %%
# Generating a correlation matrix
corr_matrix = data1.corr()

# Plot a heatmap
#This heatmap will show you how different variables (like ozone concentration, AQI, etc.) are correlated.
plt.figure(figsize = (10,8))
sns.heatmap(corr_matrix , annot=True , cmap='coolwarm')
plt.title('Correlation Matrix')
plt.show()

# %%
# How Ozone Concentration values are distributed.
plt.figure(figsize=(8, 5))
sns.histplot(data1['Daily Max 8-hour Ozone Concentration'], bins=30, kde=True)
plt.title('Distribution of Daily Max 8-hour Ozone Concentration')
plt.show()

# %%
# BoxPlots are important For detecting Outliers.
plt.figure(figsize=(8, 5))
sns.boxplot(data=data1, x='Daily Max 8-hour Ozone Concentration')
plt.title('Boxplot of Daily Max 8-hour Ozone Concentration')
plt.show()

# %%
# Checking Data Completeness
plt.figure(figsize=(8, 5))
sns.histplot(data1['Percent Complete'], bins=20)
plt.title('Data Completeness Distribution')
plt.show()

# %%
# Verify data structure
print(data1.head())
# Out:
#            Source    Site ID  POC  Daily Max 8-hour Ozone Concentration Units  \
# Date
# 2018-03-01    AQS  371010002    1                                 0.037   ppm
# 2018-03-02    AQS  371010002    1                                 0.046   ppm
# 2018-03-03    AQS  371010002    1                                 0.047   ppm
# 2018-03-04    AQS  371010002    1                                 0.045   ppm
# 2018-03-05    AQS  371010002    1                                 0.046   ppm
#
#             Daily AQI Value    Local Site Name  Daily Obs Count  \
# Date
# 2018-03-01               34  West Johnston Co.               17
# 2018-03-02               43  West Johnston Co.               17
# 2018-03-03               44  West Johnston Co.               17
# 2018-03-04               42  West Johnston Co.               17
# 2018-03-05               43  West Johnston Co.               17
#
#             Percent Complete  AQS Parameter Code AQS Parameter Description  \
# Date
# 2018-03-01               100               44201                     Ozone
# 2018-03-02               100               44201                     Ozone
# 2018-03-03               100               44201                     Ozone
# 2018-03-04               100               44201                     Ozone
# 2018-03-05               100               44201                     Ozone
#
#             Method Code  CBSA Code    CBSA Name  State FIPS Code  \
# Date
# 2018-03-01           47      39580  Raleigh, NC               37
# 2018-03-02           47      39580  Raleigh, NC               37
# 2018-03-03           47      39580  Raleigh, NC               37
# 2018-03-04           47      39580  Raleigh, NC               37
# 2018-03-05           47      39580  Raleigh, NC               37
#
#                      State  County FIPS Code    County  Site Latitude  \
# Date
# 2018-03-01  North Carolina               101  Johnston       35.59095
# 2018-03-02  North Carolina               101  Johnston       35.59095
# 2018-03-03  North Carolina               101  Johnston       35.59095
# 2018-03-04  North Carolina               101  Johnston       35.59095
# 2018-03-05  North Carolina               101  Johnston       35.59095
#
#             Site Longitude
# Date
# 2018-03-01        -78.4622
# 2018-03-02        -78.4622
# 2018-03-03        -78.4622
# 2018-03-04        -78.4622
# 2018-03-05        -78.4622

# %%
# Define the split point
split_point = int(len(data1) * 0.8)

# %%
# Split into training and test sets
train_data = data1.iloc[:split_point]
test_data = data1.iloc[split_point:]

# %%
# Plot the split data
plt.figure(figsize=(8, 6))
plt.plot(train_data.index, train_data['Daily Max 8-hour Ozone Concentration'], label='Training Data')
plt.plot(test_data.index, test_data['Daily Max 8-hour Ozone Concentration'], label='Testing Data')
plt.title('Ozone Concentration - Train and Test Split')
plt.xlabel('Date')
plt.ylabel('Ozone Concentration (ppm)')
plt.legend()
plt.show()

# %%
from statsmodels.tsa.holtwinters import ExponentialSmoothing
from sklearn.metrics import mean_absolute_error, mean_squared_error

# %%
# Assign the frequency (assuming daily data; change if different)
data1 = data1.asfreq('D')

# Verify that the index has a frequency now
print(data1.index.freq)
# Out:
# <Day>

# %%
# Initialize and fit the model on the training data
esm_model = ExponentialSmoothing(
    train_data['Daily Max 8-hour Ozone Concentration'],
    trend='add',                # Capture trend (linear trend in this case)
    seasonal='add',              # Capture seasonality (additive)
    seasonal_periods=365         # Assume yearly seasonality
)
esm_fit = esm_model.fit()
# Out:
# C:\Users\MIHIR SHAH\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)

# %%
# Forecast for the length of the test data
forecast = esm_fit.forecast(steps=len(test_data))

# Plot the results
plt.figure(figsize=(12, 6))
plt.plot(train_data.index, train_data['Daily Max 8-hour Ozone Concentration'], label='Training Data')
plt.plot(test_data.index, test_data['Daily Max 8-hour Ozone Concentration'], label='Actual Test Data')
plt.plot(test_data.index, forecast, label='Forecast', color='red')
plt.title('Ozone Concentration Forecast vs Actual')
plt.xlabel('Date')
plt.ylabel('Ozone Concentration (ppm)')
plt.legend()
plt.show()

# %%
# Calculate error metrics
mae = mean_absolute_error(test_data['Daily Max 8-hour Ozone Concentration'], forecast)
mse = mean_squared_error(test_data['Daily Max 8-hour Ozone Concentration'], forecast)

print(f"Mean Absolute Error (MAE): {mae}")
print(f"Mean Squared Error (MSE): {mse}")
# Out:
# Mean Absolute Error (MAE): 0.00790065002238407
# Mean Squared Error (MSE): 9.436872853578727e-05

# %%
plt.figure(figsize=(12, 6))
plt.plot(data1.index,data1['Daily Max 8-hour Ozone Concentration'], label='Ozone Concentration')
plt.title('Ozone Concentration Over Time')
plt.xlabel('Date')
plt.ylabel('Ozone Concentration (ppm)')
plt.legend()
plt.show()
