# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv('Combined_ozone.csv')

# %%
data.head()
# Out:
#        Date Source    Site ID  POC  Daily Max 8-hour Ozone Concentration  \
# 0  3/1/2018    AQS  371010002    1                                 0.037
# 1  3/2/2018    AQS  371010002    1                                 0.046
# 2  3/3/2018    AQS  371010002    1                                 0.047
# 3  3/4/2018    AQS  371010002    1                                 0.045
# 4  3/5/2018    AQS  371010002    1                                 0.046
#
#   Units  Daily AQI Value    Local Site Name  Daily Obs Count  \
# 0   ppm               34  West Johnston Co.               17
# 1   ppm               43  West Johnston Co.               17
# 2   ppm               44  West Johnston Co.               17
# 3   ppm               42  West Johnston Co.               17
# 4   ppm               43  West Johnston Co.               17
#
#    Percent Complete  ...  AQS Parameter Description Method Code  CBSA Code  \
# 0               100  ...                      Ozone          47      39580
# 1               100  ...                      Ozone          47      39580
# 2               100  ...                      Ozone          47      39580
# 3               100  ...                      Ozone          47      39580
# 4               100  ...                      Ozone          47      39580
#
#      CBSA Name State FIPS Code           State County FIPS Code    County  \
# 0  Raleigh, NC              37  North Carolina              101  Johnston
# 1  Raleigh, NC              37  North Carolina              101  Johnston
# 2  Raleigh, NC              37  North Carolina              101  Johnston
# 3  Raleigh, NC              37  North Carolina              101  Johnston
# 4  Raleigh, NC              37  North Carolina              101  Johnston
#
#   Site Latitude  Site Longitude
# 0      35.59095        -78.4622
# 1      35.59095        -78.4622
# 2      35.59095        -78.4622
# 3      35.59095        -78.4622
# 4      35.59095        -78.4622
#
# [5 rows x 21 columns]

# %%
data.tail()
# Out:
#             Date  Source    Site ID  POC  \
# 1665  10/13/2024  AirNow  371010002    1
# 1666  10/14/2024  AirNow  371010002    1
# 1667  10/15/2024  AirNow  371010002    1
# 1668  10/16/2024  AirNow  371010002    1
# 1669  10/17/2024  AirNow  371010002    1
#
#       Daily Max 8-hour Ozone Concentration Units  Daily AQI Value  \
# 1665                                 0.050   ppm               46
# 1666                                 0.050   ppm               46
# 1667                                 0.036   ppm               33
# 1668                                 0.031   ppm               29
# 1669                                 0.035   ppm               32
#
#         Local Site Name  Daily Obs Count  Percent Complete  ...  \
# 1665  West Johnston Co.               24               100  ...
# 1666  West Johnston Co.               24               100  ...
# 1667  West Johnston Co.               24               100  ...
# 1668  West Johnston Co.               24               100  ...
# 1669  West Johnston Co.               22                92  ...
#
#       AQS Parameter Description Method Code  CBSA Code    CBSA Name  \
# 1665                      Ozone          19      39580  Raleigh, NC
# 1666                      Ozone          19      39580  Raleigh, NC
# 1667                      Ozone          19      39580  Raleigh, NC
# 1668                      Ozone          19      39580  Raleigh, NC
# 1669                      Ozone          19      39580  Raleigh, NC
#
#      State FIPS Code           State County FIPS Code    County Site Latitude  \
# 1665              37  North Carolina              101  Johnston      35.59095
# 1666              37  North Carolina              101  Johnston      35.59095
# 1667              37  North Carolina              101  Johnston      35.59095
# 1668              37  North Carolina              101  Johnston      35.59095
# 1669              37  North Carolina              101  Johnston      35.59095
#
#       Site Longitude
# 1665        -78.4622
# 1666        -78.4622
# 1667        -78.4622
# 1668        -78.4622
# 1669        -78.4622
#
# [5 rows x 21 columns]

# %%
np.shape(data)
# Out:
# (1670, 21)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1670 entries, 0 to 1669
# Data columns (total 21 columns):
#  #   Column                                Non-Null Count  Dtype
# ---  ------                                --------------  -----
#  0   Date                                  1670 non-null   object
#  1   Source                                1670 non-null   object
#  2   Site ID                               1670 non-null   int64
#  3   POC                                   1670 non-null   int64
#  4   Daily Max 8-hour Ozone Concentration  1670 non-null   float64
#  5   Units                                 1670 non-null   object
#  6   Daily AQI Value                       1670 non-null   int64
#  7   Local Site Name                       1670 non-null   object
#  8   Daily Obs Count                       1670 non-null   int64
#  9   Percent Complete                      1670 non-null   int64
#  10  AQS Parameter Code                    1670 non-null   int64
#  11  AQS Parameter Description             1670 non-null   object
#  12  Method Code                           1670 non-null   int64
#  13  CBSA Code                             1670 non-null   int64
#  14  CBSA Name                             1670 non-null   object
#  15  State FIPS Code                       1670 non-null   int64
#  16  State                                 1670 non-null   object
#  17  County FIPS Code                      1670 non-null   int64
#  18  County                                1670 non-null   object
#  19  Site Latitude                         1670 non-null   float64
#  20  Site Longitude                        1670 non-null   float64
# dtypes: float64(3), int64(10), object(8)
# memory usage: 274.1+ KB

# %%
data.describe()
# Out:
#            Site ID     POC  Daily Max 8-hour Ozone Concentration  \
# count       1670.0  1670.0                           1670.000000
# mean   371010002.0     1.0                              0.042292
# std            0.0     0.0                              0.009885
# min    371010002.0     1.0                              0.012000
# 25%    371010002.0     1.0                              0.035000
# 50%    371010002.0     1.0                              0.043000
# 75%    371010002.0     1.0                              0.049000
# max    371010002.0     1.0                              0.082000
#
#        Daily AQI Value  Daily Obs Count  Percent Complete  AQS Parameter Code  \
# count      1670.000000      1670.000000       1670.000000              1670.0
# mean         40.072455        18.320359        105.212575             44201.0
# std          11.565642         4.075501         22.479277                 0.0
# min          11.000000        13.000000         76.000000             44201.0
# 25%          32.000000        17.000000        100.000000             44201.0
# 50%          40.000000        17.000000        100.000000             44201.0
# 75%          45.000000        17.000000        100.000000             44201.0
# max         140.000000        34.000000        200.000000             44201.0
#
#        Method Code  CBSA Code  State FIPS Code  County FIPS Code  \
# count  1670.000000     1670.0           1670.0            1670.0
# mean     43.730539    39580.0             37.0             101.0
# std       8.994664        0.0              0.0               0.0
# min      19.000000    39580.0             37.0             101.0
# 25%      47.000000    39580.0             37.0             101.0
# 50%      47.000000    39580.0             37.0             101.0
# 75%      47.000000    39580.0             37.0             101.0
# max      47.000000    39580.0             37.0             101.0
#
#        Site Latitude  Site Longitude
# count   1.670000e+03    1.670000e+03
# mean    3.559095e+01   -7.846220e+01
# std     5.117440e-13    2.103836e-12
# min     3.559095e+01   -7.846220e+01
# 25%     3.559095e+01   -7.846220e+01
# 50%     3.559095e+01   -7.846220e+01
# 75%     3.559095e+01   -7.846220e+01
# max     3.559095e+01   -7.846220e+01

# %%
print(data.isnull().sum()) # No Missing Values
# Out:
# Date                                    0
# Source                                  0
# Site ID                                 0
# POC                                     0
# Daily Max 8-hour Ozone Concentration    0
# Units                                   0
# Daily AQI Value                         0
# Local Site Name                         0
# Daily Obs Count                         0
# Percent Complete                        0
# AQS Parameter Code                      0
# AQS Parameter Description               0
# Method Code                             0
# CBSA Code                               0
# CBSA Name                               0
# State FIPS Code                         0
# State                                   0
# County FIPS Code                        0
# County                                  0
# Site Latitude                           0
# Site Longitude                          0
# dtype: int64

# %%
data.dtypes
# Out:
# Date                                     object
# Source                                   object
# Site ID                                   int64
# POC                                       int64
# Daily Max 8-hour Ozone Concentration    float64
# Units                                    object
# Daily AQI Value                           int64
# Local Site Name                          object
# Daily Obs Count                           int64
# Percent Complete                          int64
# AQS Parameter Code                        int64
# AQS Parameter Description                object
# Method Code                               int64
# CBSA Code                                 int64
# CBSA Name                                object
# State FIPS Code                           int64
# State                                    object
# County FIPS Code                          int64
# County                                   object
# Site Latitude                           float64
# Site Longitude                          float64
# dtype: object

# %%
print(data["POC"].duplicated().sum())
# Out:
# 1669

# %%
# Generating a correlation matrix
corr_matrix = data.corr()

# Plot a heatmap
#This heatmap will show you how different variables (like ozone concentration, AQI, etc.) are correlated.
plt.figure(figsize = (10,8))
sns.heatmap(corr_matrix , annot=True , cmap='coolwarm')
plt.title('Correlation Matrix')
plt.show()

# %%
# How Ozone Concentration values are distributed.
plt.figure(figsize=(8, 5))
sns.histplot(data['Daily Max 8-hour Ozone Concentration'], bins=30, kde=True)
plt.title('Distribution of Daily Max 8-hour Ozone Concentration')
plt.show()

# %%
# BoxPlots are important For detecting Outliers.
plt.figure(figsize=(8, 5))
sns.boxplot(data=data, x='Daily Max 8-hour Ozone Concentration')
plt.title('Boxplot of Daily Max 8-hour Ozone Concentration')
plt.show()

# %%
# Checking Data Completeness
plt.figure(figsize=(8, 5))
sns.histplot(data['Percent Complete'], bins=20)
plt.title('Data Completeness Distribution')
plt.show()
